# %%
using PDFmerger

Path_Home = raw"D:\TEMP\Fleadh 2025"

Folder=[]
for i in 1:10
    Path_Pdf = joinpath(Path_Home, "$(i)August Events.pdf")
	println(Path_Pdf)
	println(isfile(Path_Pdf))
	Folder = vcat(Folder,Path_Pdf)
end

Folder = string.(Folder)
println(Folder)
# string.(Folder)

Path_Save =  joinpath(Path_Home, "FleadhProgram_2025.pdf")
merge_pdfs(Folder, Path_Save)

# merge_pdfs(["file_1.pdf", "file_1.pdf", "file_2.pdf"], "FleadhProgram.pdf")
# Out:
# D:\TEMP\Fleadh 2025\1August Events.pdf
# true
# D:\TEMP\Fleadh 2025\2August Events.pdf
# true
# D:\TEMP\Fleadh 2025\3August Events.pdf
# true
# D:\TEMP\Fleadh 2025\4August Events.pdf
# true
# D:\TEMP\Fleadh 2025\5August Events.pdf
# true
# D:\TEMP\Fleadh 2025\6August Events.pdf
# true
# D:\TEMP\Fleadh 2025\7August Events.pdf
# true
# D:\TEMP\Fleadh 2025\8August Events.pdf
# true
# D:\TEMP\Fleadh 2025\9August Events.pdf
# true
# D:\TEMP\Fleadh 2025\10August Events.pdf
# true
# ["D:\\TEMP\\Fleadh 2025\\1August Events.pdf", "D:\\TEMP\\Fleadh 2025\\2August Events.pdf", "D:\\TEMP\\Fleadh 2025\\3August Events.pdf", "D:\\TEMP\\Fleadh 2025\\4August Events.pdf", "D:\\TEMP\\Fleadh 2025\\5August Events.pdf", "D:\\TEMP\\Fleadh 2025\\6August Events.pdf", "D:\\TEMP\\Fleadh 2025\\7August Events.pdf", "D:\\TEMP\\Fleadh 2025\\8August Events.pdf", "D:\\TEMP\\Fleadh 2025\\9August Events.pdf", "D:\\TEMP\\Fleadh 2025\\10August Events.pdf"]
# IOError: unlink("D:\\TEMP\\Fleadh 2025\\FleadhProgram_2025.pdf"): resource busy or locked (EBUSY)
#
#
#
# Stacktrace:
#
#   [1] uv_error
#
#     @ .\libuv.jl:106 [inlined]
#
#   [2] unlink(p::String)
#
#     @ Base.Filesystem .\file.jl:1105
#
#   [3] rm(path::String; force::Bool, recursive::Bool)
#
#     @ Base.Filesystem .\file.jl:283
#
#   [4] rm
#
#     @ .\file.jl:273 [inlined]
#
#   [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
#
#     @ Base.Filesystem .\file.jl:332
#
#   [6] checkfor_mv_cp_cptree
#
#     @ .\file.jl:318 [inlined]
#
#   [7] #mv#15
#
#     @ .\file.jl:427 [inlined]
#
#   [8] mv
#
#     @ .\file.jl:426 [inlined]
#
#   [9] merge_pdfs(files::Vector{String}, destination::String; cleanup::Bool)
#
#     @ PDFmerger C:\Users\jpollacco.local\.julia\packages\PDFmerger\Ys3uk\src\PDFmerger.jl:61
#
#  [10] merge_pdfs(files::Vector{String}, destination::String)
#
#     @ PDFmerger C:\Users\jpollacco.local\.julia\packages\PDFmerger\Ys3uk\src\PDFmerger.jl:24
#
#  [11] top-level scope
#
#     @ d:\JOE\MAIN\MODELS\AquaPore_Toolkit\src\Temporary\TempJupiter\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:18
