# %% [markdown]
# # _______________________ START: READING KsGroup _______________________

# %%
using CSV, Tables, DataFrames
Path_Input = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\NSDR_NSD_wr_data_Oct_2024.csv"

Data = CSV.read(Path_Input, DataFrame;  missingstring=["NA", "NAN", ""], ignoreemptyrows=true)
# select=Name_Select,
# Out:
# 21834×121 DataFrame
#    Row │ siteid                             nsd_id                             ⋯
#        │ String                             String                             ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ a4071614-dff6-4eaa-942b-630fa3e7…  Waitoa silt loam                   ⋯
#      2 │ a4071614-dff6-4eaa-942b-630fa3e7…  Waitoa silt loam
#      3 │ 7c868691-67f8-4ebb-b887-bc7e2b9e…  Waihou silt loam
#      4 │ 7c868691-67f8-4ebb-b887-bc7e2b9e…  Waihou silt loam
#      5 │ b0d62bc8-1b95-40cf-a6b5-dcd460ef…  Hamilton clay loam                 ⋯
#      6 │ b0d62bc8-1b95-40cf-a6b5-dcd460ef…  Hamilton clay loam
#      7 │ b0d62bc8-1b95-40cf-a6b5-dcd460ef…  Hamilton clay loam
#      8 │ 6c2f0026-1252-4a19-bf6f-d9b410d4…  Te Puninga silt loam
#    ⋮   │                 ⋮                                  ⋮                  ⋱
#  21828 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479                            ⋯
#  21829 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479
#  21830 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479
#  21831 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479
#  21832 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479                            ⋯
#  21833 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479
#  21834 │ 55-bf13e145-c882-44e4-b17f-8e94b…  SB08479
#                                               119 columns and 21819 rows omitted

# %%
Data_Names = show(names(Data))
# Out:
# ["siteid", "nsd_id", "dataset", "parentdatasource", "labidentifier", "x_nztm", "y_nztm", "rdate", "soilorder", "soilgroup", "horizonnumber", "horizontop", "horizonbottom", "sampletop", "samplebottom", "sand", "silt", "clay", "fineclay", "finesand", "mediumsand", "coarsesand", "fh", "fh_est", "profiledrainage", "carbon", "fineearthdrybulkdensity", "rockoffines", "particledensity", "tp", "wr0kpa", "wr0.1kpa", "wr0.2kpa", "wr0.4kpa", "wr0.7kpa", "wr1.0kpa", "wr2.0kpa", "wr2.5kpa", "wr5kpa", "wr10kpa", "wr20kpa", "wr40kpa", "wr50kpa", "wr100kpa", "wr300kpa", "wr1500kpa", "wr1500kpa_uom", "wr100kpa_uom", "wr40kpa_uom", "wr20kpa_uom", "wr10kpa_uom", "wr5kpa_uom", "fe2", "fe5", "fe6", "fe10", "fe20", "fe40", "fe50", "fe60", "fe63", "fe100", "fe125", "fe200", "fe250", "fe500", "fe600", "fe1000", "fe2000", "ksat", "k10", "k40", "k70", "k100", "delete", "delete_reason", "comment", "rockclassfines", "sand_est", "silt_est", "clay_est", "sand_psd", "silt_psd", "clay_psd", "sand_est_aus", "silt_est_aus", "clay_est_aus", "sand_est_int", "silt_est_int", "clay_est_int", "fhcompact", "identifier", "horizonnumber.y", "horizontop.y", "horizonbottom.y", "sampletop.y", "samplebottom.y", "fh.y", "RockClassFines", "RockClassGroup", "drainage", "topsoil", "organic", "texture", "pedsize", "strength", "tephra", "stoniness", "wr_airdried_grav", "disjointclusters", "thiscluster", "w1", "w2", "sampledepth", "samplethickness", "horizonthickness", "trainstatus", "region_ascii", "region_macron", "simple_soilorder", "subgroup_soilorder"]

# %%
# dropmissing(Data, :ksat)
Data[!, "ksat_True"]   = .!((ismissing.(Data.ksat)))
Data[!, "k10_True"]  = .!((ismissing.(Data.k10)))
Data[!, "K40_True" ] = .!((ismissing.(Data.k40)))
Data[!, "K70_True" ] = .!((ismissing.(Data.k70)))
Data[!, "K100_True"] = .!((ismissing.(Data.k100)))

Data[!,"wr0kpa_True"]      = .!((ismissing.(Data.tp)))
Data[! ,"wr0.1kpa_True"]   = .!((ismissing.(Data."wr0.1kpa")))
Data[! ,"wr0.2kpa_True"]   = .!((ismissing.(Data."wr0.2kpa")))
Data[! ,"wr0.4kpa_True"]   = .!((ismissing.(Data."wr0.4kpa")))
Data[! ,"wr0.7kpa_True"]   = .!((ismissing.(Data."wr0.7kpa")))
Data[! , "wr1.0kpa_True"]  = .!((ismissing.(Data."wr1.0kpa")))
Data[! , "wr2.0kpa_True"]  = .!((ismissing.(Data."wr2.0kpa")))
Data[! , "wr2.5kpa_True"]  = .!((ismissing.(Data."wr2.5kpa")))
Data[! , "wr5kpa_True"]    = .!((ismissing.(Data."wr5kpa")))
Data[! , "wr10kpa_True"]   = .!((ismissing.(Data."wr10kpa")))
Data[! , "wr20kpa_True"]   = .!((ismissing.(Data."wr20kpa")))
Data[! , "wr40kpa_True"]   = .!((ismissing.(Data."wr40kpa")))
Data[! , "wr100kpa_True"]  = .!((ismissing.(Data."wr100kpa")))
Data[!  ,"wr300kpa_True"]  = .!((ismissing.(Data."wr300kpa")))
Data[!  ,"wr1500kpa_True"] = .!((ismissing.(Data."wr1500kpa")))

Data[!  ,"clay_True"] = .!((ismissing.(Data."clay_est")))

Data[!, "K_N"] = Data.ksat_True .+ Data.k10_True .+ Data.K40_True .+ Data.K70_True .+ Data.K100_True

Data[!,"Wr_N"] = Data.wr0kpa_True .+ Data."wr0.1kpa_True" .+ Data."wr0.2kpa_True".+ Data."wr0.4kpa_True".+ Data."wr0.7kpa_True" .+ Data."wr1.0kpa_True" .+  Data."wr2.0kpa_True"  .+  Data."wr2.5kpa_True" .+ +  Data."wr5kpa_True" .+  Data."wr10kpa_True" .+  Data."wr20kpa_True" .+  Data."wr40kpa_True" .+ Data."wr100kpa_True" .+ Data."wr300kpa_True" .+ Data."wr1500kpa_True";

# %% [markdown]
# ## Select soils

# %%
Data_Names = show(names(Data))
# Out:
# ["siteid", "nsd_id", "dataset", "parentdatasource", "labidentifier", "x_nztm", "y_nztm", "rdate", "soilorder", "soilgroup", "horizonnumber", "horizontop", "horizonbottom", "sampletop", "samplebottom", "sand", "silt", "clay", "fineclay", "finesand", "mediumsand", "coarsesand", "fh", "fh_est", "profiledrainage", "carbon", "fineearthdrybulkdensity", "rockoffines", "particledensity", "tp", "wr0kpa", "wr0.1kpa", "wr0.2kpa", "wr0.4kpa", "wr0.7kpa", "wr1.0kpa", "wr2.0kpa", "wr2.5kpa", "wr5kpa", "wr10kpa", "wr20kpa", "wr40kpa", "wr50kpa", "wr100kpa", "wr300kpa", "wr1500kpa", "wr1500kpa_uom", "wr100kpa_uom", "wr40kpa_uom", "wr20kpa_uom", "wr10kpa_uom", "wr5kpa_uom", "fe2", "fe5", "fe6", "fe10", "fe20", "fe40", "fe50", "fe60", "fe63", "fe100", "fe125", "fe200", "fe250", "fe500", "fe600", "fe1000", "fe2000", "ksat", "k10", "k40", "k70", "k100", "delete", "delete_reason", "comment", "rockclassfines", "sand_est", "silt_est", "clay_est", "sand_psd", "silt_psd", "clay_psd", "sand_est_aus", "silt_est_aus", "clay_est_aus", "sand_est_int", "silt_est_int", "clay_est_int", "fhcompact", "identifier", "horizonnumber.y", "horizontop.y", "horizonbottom.y", "sampletop.y", "samplebottom.y", "fh.y", "RockClassFines", "RockClassGroup", "drainage", "topsoil", "organic", "texture", "pedsize", "strength", "tephra", "stoniness", "wr_airdried_grav", "disjointclusters", "thiscluster", "w1", "w2", "sampledepth", "samplethickness", "horizonthickness", "trainstatus", "region_ascii", "region_macron", "simple_soilorder", "subgroup_soilorder", "ksat_True", "k10_True", "K40_True", "K70_True", "K100_True", "wr0kpa_True", "wr0.1kpa_True", "wr0.2kpa_True", "wr0.4kpa_True", "wr0.7kpa_True", "wr1.0kpa_True", "wr2.0kpa_True", "wr2.5kpa_True", "wr5kpa_True", "wr10kpa_True", "wr20kpa_True", "wr40kpa_True", "wr100kpa_True", "wr300kpa_True", "wr1500kpa_True", "clay_True", "K_N", "Wr_N"]

# %%
# 464 data: Data.Wr_N .≥ 4 .&& Data.wr0kpa_True .== 1 .&& Data.wr1500kpa_True .== 1
# 147 data: Data.Wr_N .≥ 4 .&& Data.wr0kpa_True .== 1 .&& Data.wr1500kpa_True .== 1 .&& Data.K_N .≥ 1
# 93 data: Data.Wr_N .≥ 4 .&& Data.wr0kpa_True .== 1 .&& Data.wr1500kpa_True .== 1 .&& Data.K_N .≥ 2
# 8 data: Data.Wr_N .≥ 4 .&& Data.wr0kpa_True .== 1 .&& Data.wr1500kpa_True .== 1 .&& Data.K_N .≥ 3

RowSelector_1 = Data.Wr_N .≥ 4 .&& Data.wr0kpa_True .== 1 .&& Data.wr1500kpa_True .== 1 .&& Data.K_N .≥ 2 .&& Data.clay_True

Data_Names = names(Data)

println(sum(RowSelector_1))
# Out:
# 296

# %% [markdown]
# ## Writting to AquaPore-ToolKit

# %%
# --- The θ(Ψ) function --- 
Ψ_Ψθ = [1.0, 0.2, 0.4, 0.7, 1.0, 2.0,2.5,5.0, 10.0, 20.0, 40.0, 100.0, 300.0, 1500] .* 100.0

Data_Ψθ = Matrix(Data[RowSelector_1, ["wr0.1kpa", "wr0.2kpa", "wr0.4kpa", "wr0.7kpa", "wr1.0kpa", "wr2.0kpa", "wr2.5kpa", "wr5kpa", "wr10kpa", "wr20kpa", "wr40kpa", "wr100kpa", "wr300kpa", "wr1500kpa"]])

Data_Ψθ_True = Matrix(Data[RowSelector_1, [ "wr0.1kpa_True", "wr0.2kpa_True", "wr0.4kpa_True", "wr0.7kpa_True", "wr1.0kpa_True", "wr2.0kpa_True", "wr2.5kpa_True", "wr5kpa_True", "wr10kpa_True", "wr20kpa_True", "wr40kpa_True", "wr100kpa_True", "wr300kpa_True", "wr1500kpa_True"]])

# --- The K(Ψ) function --- 
Ψ_ΨK = [0.0, 10.0, 40.0, 70.0, 100.0] .* 100.0

Data_KΨ = Matrix(Data[RowSelector_1, ["ksat", "k10", "k40", "k70", "k100"]])
Data_KΨ_True = Matrix(Data[RowSelector_1, ["ksat_True", "k10_True", "K40_True", "K70_True", "K100_True"]]);

# %% [markdown]
# ### Running data

# %%
# Writting θ(ψ)
N_Row, N_Column = size(Data_Ψθ)

Ψdata = []
θdata = []
Id = []
Count = 1
for iZ = 1: N_Row
	for (iΨ, iiΨ) in enumerate(Ψ_Ψθ)
		if Data_Ψθ_True[iZ, iΨ]
			append!(Ψdata, iiΨ)
			append!(θdata, Data_Ψθ[iZ, iΨ])
			append!(Id, Count)		
		end  # if
	end
	Count += 1
end

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_ThetaH.csv"
Header = ["Id","H[mm]","Theta[0-1]"]

CSV.write(Path_Output, Tables.table([Id Ψdata θdata]), writeheader=true, header=Header, bom=true)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_ThetaH.csv"

# %%
# Writting K(ψ)
N_Row, N_Column = size(Data_KΨ)

Ψdata = []
Kdata = []
Id = []
Count = 1
for iZ = 1: N_Row
	for (iΨ, iiΨ) in enumerate(Ψ_ΨK)
		if Data_KΨ_True[iZ, iΨ]
			append!(Ψdata, iiΨ)
			append!(Kdata, Data_KΨ[iZ, iΨ] / (60.0 * 60.0)) # convert mm/hour -> mm/second
			append!(Id, Count)		
		end  # if
	end
	Count += 1
end

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_KunsatH.csv"
Header = ["Id" ,"H[mm]" , "Kunsat[mm_s]"]

CSV.write(Path_Output, Tables.table([Id Ψdata Kdata]), writeheader=true, header=Header, bom=true)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_KunsatH.csv"

# %%
# Writting id
Id = []
Select = ones(Int64, N_Row)
for iZ = 1: N_Row
	append!(Id, iZ)		
end

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_IdSelect.csv"
Header = ["Id" ,"Select_1"]

CSV.write(Path_Output, Tables.table([Id Select]), writeheader=true, header=Header, bom=true)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_IdSelect.csv"

# %%
# Writting TotalPorosity
Id = []
TotalPorosity = Matrix(Data[RowSelector_1, ["tp"]])

RockFragment = zeros(Int64, N_Row)
for iZ = 1: N_Row
	append!(Id, iZ)	
end

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_TotalPorosity.csv"
Header = ["Id", "TotalPorosity[0-1]", "RockFragment[0-1]"]

CSV.write(Path_Output, Tables.table([Id TotalPorosity RockFragment]), writeheader=true, header=Header, bom=true)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_TotalPorosity.csv"

# %%
# Writting MetaData
DataSelect = ["siteid", "nsd_id", "dataset", "x_nztm", "y_nztm", "rdate", "soilorder", "horizonnumber",  "fh",  "carbon", "sand_est", "fhcompact", "fh.y", "RockClassFines", "RockClassGroup", "drainage", "topsoil", "organic", "texture", "pedsize", "strength", "tephra", "stoniness", "disjointclusters", "thiscluster", "w1", "w2", "sampledepth", "samplethickness", "horizonthickness", "region_ascii", "region_macron", "simple_soilorder"]


Data_Select1 = Data[RowSelector_1, DataSelect];

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_MetaData.csv"
CSV.write(Path_Output, Data_Select1)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_MetaData.csv"

# %%
# Writting PSD
Clay = Matrix(Data[RowSelector_1, ["clay_est"]])
Silt = Matrix(Data[RowSelector_1, ["silt_est"]])
Sand = Matrix(Data[RowSelector_1, ["sand_est"]])

Id = []
Diameter = []
Cumul_Psd = []
Count = 1
for iZ = 1: N_Row

	append!(Diameter, 0.002)
	append!(Cumul_Psd, Clay[iZ])
	append!(Id, Count)
	
	
	append!(Diameter, 0.06)
	append!(Cumul_Psd, Clay[iZ] + Silt[iZ])
	append!(Id, Count)

	append!(Diameter, 2.0)
	append!(Cumul_Psd, 1.0)
	append!(Id, Count)

	Count += 1
end

Path_Output = raw"D:\MAIN\PROJETCS\Ks_Grouping\DATA\OUTPUT\KsGroup_Psd.csv"
Header = ["Id", "Diameter[mm]", "Cumul_Psd"]

CSV.write(Path_Output, Tables.table([Id Diameter Cumul_Psd]), writeheader=true, header=Header, bom=true)
# Out:
# "D:\\MAIN\\PROJETCS\\Ks_Grouping\\DATA\\OUTPUT\\KsGroup_Psd.csv"
